# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelpinheiro/projetas/blob/main/Projetas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instalando o PySpark no Google Colab
#
# Instalar o PySpark não é um processo direto como de praxe em Python. Não basta usar um pip install apenas. Na verdade, antes de tudo é necessário instalar dependências como o Java 8, Apache Spark 2.3.2 junto com o Hadoop 2.7.

# %%
#instalar as dependências
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q https://archive.apache.org/dist/spark/spark-2.4.4/spark-2.4.4-bin-hadoop2.7.tgz
# !tar xf spark-2.4.4-bin-hadoop2.7.tgz
# !pip install -q findspark
# !pip install -q inflection
# !pip install unidecode
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting unidecode
#   Downloading Unidecode-1.3.4-py3-none-any.whl (235 kB)
#      |████████████████████████████████| 235 kB 5.1 MB/s
# Installing collected packages: unidecode
# Successfully installed unidecode-1.3.4

# %% [markdown]
# A próxima etapa é configurar as variáveis de ambiente, pois isso habilita o ambiente do Colab a identificar corretamente onde as dependências estão rodando.
#
# Para conseguir “manipular” o terminal e interagir como ele, você pode usar a biblioteca os.

# %%
# configurar as variáveis de ambiente
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.4-bin-hadoop2.7"

# tornar o pyspark "importável"
import findspark
findspark.init('spark-2.4.4-bin-hadoop2.7')

# iniciar uma sessão local e importar dados do Airbnb
from pyspark.sql import SparkSession, SQLContext
from pyspark.sql.types import StructType,StructField, StringType, IntegerType
from pyspark.sql.functions import split


import inflection
import re
import unidecode

sc = SparkSession.builder.master('local[*]').getOrCreate()

# %%
# download do http para arquivo local
# !wget --quiet --show-progress https://github.com/marcelpinheiro/projetas/raw/main/AIR_CIA.rar
# !wget --quiet --show-progress https://github.com/marcelpinheiro/projetas/raw/main/VRA.rar

#Descompactando arquivos
# !unrar x /content/VRA.rar
# !unrar x /content/AIR_CIA.rar
# Out:
# AIR_CIA.rar         100%[===================>]   3.79K  --.-KB/s    in 0s
# VRA.rar             100%[===================>]   6.54M  --.-KB/s    in 0.08s
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/VRA.rar
#
# Creating    VRA                                                       OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/AIR_CIA.rar
#
# Creating    AIR_CIA                                                   OK
#   OK
#   OK
#   OK
# All OK

# %% [markdown]
# # Views

# %%
# df_air_cia= sc.read.option("recursiveFileLookup","true").option("header","true").option("delimiter", ";").csv("/content/AIR_CIA")

# %% [markdown]
# Com tudo pronto, vamos rodar uma sessão local para testar se a instalação funcionou corretamente.

# %% [markdown]
# ## VRA

# %%
df_vra = sc.read.json("/content/VRA/*.json")



for col in df_vra.columns:    
  df_vra = df_vra.withColumnRenamed(col,unidecode.unidecode(col))
  df_vra = df_vra.withColumnRenamed(col,inflection.underscore(col))

df_vra.registerTempTable("vra")
df_vra = sc.sql("select * from vra")
df_vra.show()
# Out:
# +-------------------+-------------------+-----------------+-------------------+---------------+--------------------+-------------------+----------------+---------+-------------------+-------------------+-----------+
# |   chegada_prevista|       chegada_real|CodigoAutorizacao|CodigoJustificativa|CodigoTipoLinha|ICAOAerodromoDestino|ICAOAerodromoOrigem|ICAOEmpresaAerea|NumeroVoo|   partida_prevista|       partida_real|SituacaoVoo|
# |2021-11-02 10:40:00|2021-11-02 10:36:00|                0|                N/A|              X|                SBGR|               KORD|             UAL|     0845|2021-11-02 00:40:00|2021-11-02 00:36:00|  REALIZADO|
# |2021-11-04 10:40:00|2021-11-04 10:32:00|                0|                N/A|              X|                SBGR|               KORD|             UAL|     0845|2021-11-04 00:40:00|2021-11-04 00:47:00|  REALIZADO|
# |2021-11-06 10:40:00|2021-11-06 12:38:00|                0|                N/A|              X|                SBGR|               KORD|             UAL|     0845|2021-11-06 00:40:00|2021-11-06 02:27:00|  REALIZADO|
# |2021-11-08 10:40:00|2021-11-08 10:23:00|                0|                N/A|              X|                SBGR|               KORD|             UAL|     0845|2021-11-08 00:40:00|2021-11-08 00:28:00|  REALIZADO|
# |2021-11-07 10:40:00|2021-11-07 10:44:00|                0|                N/A|              X|                SBGR|               KORD|             UAL|     0845|2021-11-07 00:40:00|2021-11-07 00:44:00|  REALIZADO|
# +-------------------+-------------------+-----------------+-------------------+---------------+--------------------+-------------------+----------------+---------+-------------------+-------------------+-----------+
# only showing top 20 rows

# %% [markdown]
# ## AIR_CIA

# %%
df_air_cia = sc.read.option("delimiter",";").option("header","true").csv("/content/AIR_CIA/*.csv")

# Dividindo a coluna ICAO IATA
df_air_cia = df_air_cia.withColumn('icao', split(df_air_cia['ICAO IATA'], ' ').getItem(0)) \
       .withColumn('iata', split(df_air_cia['ICAO IATA'], ' ').getItem(1)) 
df_air_cia = df_air_cia.drop('ICAO IATA')


for col in df_air_cia.columns:
    df_air_cia = df_air_cia.withColumnRenamed(col,unidecode.unidecode(col))    
    df_air_cia = df_air_cia.withColumnRenamed(col, re.sub(r'(?<!^)(\s)(?=[A-Z])', '_', col).lower())    

for col in df_air_cia.columns:    
    
    df_air_cia = df_air_cia.withColumnRenamed(col, re.sub(r' ', '', col))


df_air_cia.registerTempTable("air_cia")
df_air_cia = sc.sql("select * from air_cia")

# %%
df_air_cia.show(50)
# Out:
# +--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+----+----+
# |         RazaoSocial|              cnpj|    AtividadesAereas|        EnderecoSede|            telefone|              e-mail|  DecisaoOperacional|DataDecisaoOperacional|validade_operacional|icao|iata|
# +--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+----+----+
# |ABSA - AEROLINHAS...|00.074.635/0001-33|TRANSPORTE AÉREO ...|AEROPORTO INTERNA...|      (11) 5582-8055|      gar@tam.com.br|       DECISÃO Nº 41|            22/04/2015|          23/04/2025| LTG|  M3|
# |AEROSUL TÁXI AÉRE...|27.315.694/0001-02|SERVIÇOS AÉREOS P...|RODOVIA PR 218, K...|      (43) 3176-4030|operacoes@aerosul...|      DECISÃO Nº 282|            10/02/2021|                null| ASO|  2S|
# |ASTA LINHAS AÉREA...|12.703.737/0001-50|SERVIÇOS AÉREOS P...|AV GOVERNADOR JOÃ...|(65) 3614-2684 / ...|                null|      DECISÃO Nº 115|            31/07/2019|          02/08/2024| SUL|  0A|
# | PRIME TÁXI AIR LTDA|23.568.370/0001-25|TÁXI-AÉREO, TRANS...|AL. RIO NEGRO, 58...|(11) 41958307 / (...|mmatta@primefract...|      DECISÃO Nº 237|            17/12/2020|          18/12/2025|null|null|
# |SIDERAL LINHAS AÉ...|10.919.908/0001-57|TRANSPORTE AÉREO ...|RODOVIA CONTORNO ...|(41) 3116-9000 / ...|office@siderallin...|       DECISÃO Nº 37|            05/03/2020|          06/03/2025| SID|  0S|
# |RIMA - RIO MADEIR...|04.778.630/0001-42|LIGAÇÃO AÉREA SIS...|AV. LAURO SODRÉ, ...|      (69) 3225-8000|                null|      DECISÃO Nº 116|            26/07/2017|          27/07/2022| RIM|  0R|
# |RTS - ROTA DO SOL...|01.904.715/0001-31|LIGAÇÃO AÉREA SIS...|PRAÇA EDUARDO GOM...|      (85) 3272-3555|quadros@voerotado...|       DECISÃO Nº 21|            13/02/2019|          15/02/2024| CKP|null|
# +--------------------+------------------+--------------------+--------------------+--------------------+--------------------+--------------------+----------------------+--------------------+----+----+

# %%
import requests

def consultaAerodromos(icao):
  url = "https://airport-info.p.rapidapi.com/airport"

  querystring = {"icao":icao}

  headers = {
    "X-RapidAPI-Host": "airport-info.p.rapidapi.com",
    "X-RapidAPI-Key": "31cc9d652dmsh7cd96c1805671fap19380djsnb46510a1d18c"
  }

  response = requests.request("GET", url, headers=headers, params=querystring)
  return response

# %% [markdown]
# ## API

# %%
import json

icao_list = df_vra.select("ICAOAerodromoOrigem").distinct().rdd.flatMap(lambda x: x).collect()
icao_list2 = df_vra.select("ICAOAerodromoDestino").distinct().rdd.flatMap(lambda x: x).collect()
icao_list_final = icao_list + icao_list2

# icao_list_final = ['KORD']

listay = []

for i in icao_list_final:     
  listay.append(json.loads(consultaAerodromos(i).text))

schema = StructType([ \
  StructField("city",StringType(),True), \
  StructField("country",StringType(),True), \
  StructField("country_iso",StringType(),True), \
  StructField("county",StringType(),True), \
  StructField("iata",StringType(),True), \
  StructField("icao",StringType(),True), \
  StructField("id",StringType(),True), \
  StructField("latitude",StringType(),True), \
  StructField("location",StringType(),True), \
  StructField("longitude",StringType(),True), \
  StructField("name",StringType(),True), \
  StructField("phone",StringType(),True), \
  StructField("postal_code",StringType(),True), \
  StructField("state",StringType(),True), \
  StructField("street",StringType(),True), \
  StructField("street_number",StringType(),True), \
  StructField("uct",StringType(),True), \
  StructField("website",StringType(),True), \
  ])


dataframe = sc.createDataFrame(data=listay,schema=schema)
# dataframe.show()

dataframe.registerTempTable("aerodromos")
dataframe = sc.sql("select * from aerodromos")
dataframe.show()
# Out:
# +----------------+--------------------+-----------+-------------------+----+----+----+----------+--------------------+----------+--------------------+-----------------+-----------+--------------------+--------------------+-------------+----+--------------------+
# |            city|             country|country_iso|             county|iata|icao|  id|  latitude|            location| longitude|                name|            phone|postal_code|               state|              street|street_number| uct|             website|
# +----------------+--------------------+-----------+-------------------+----+----+----+----------+--------------------+----------+--------------------+-----------------+-----------+--------------------+--------------------+-------------+----+--------------------+
# |       Anchorage|       United States|         US|          Anchorage| ANC|PANC| 277| 61.175888|Anchorage, Alaska...|-149.99008|Ted Stevens Ancho...|  +1 907-266-2526|      99502|              Alaska|West Internationa...|         5000|-480|http://dot.state....|
# |           Wuhan|               China|         CN|                   | WUH|ZHHH|8291| 30.776617| Wuhan, Hubei, China| 114.21245|Wuhan Tianhe Inte...|     +86 27 96577|           |               Hubei|                    |             | 480|                    |
# |                |              Brazil|         BR|         Uruguaiana| URG|SBUG|7845|-29.783995|Uruguaiana, Rio G...|  -57.0357|Rubem Berta Inter...| +55 55 3413-1314|  97513-780|   Rio Grande do Sul|Acesso Marechal S...|          s/n|-180|http://www4.infra...|
# |            null|                null|       null|               null|null|null|null|      null|                null|      null|                null|             null|       null|                null|                null|         null|null|                null|
# |       Abu Dhabi|United Arab Emirates|         AE|                   | AUH|OMAA| 431| 24.441938|Abu Dhabi, United...| 54.650074|Abu Dhabi Interna...|  +971 2 505 5555|           |           Abu Dhabi|                    |             | 240|http://www.abudha...|
# +----------------+--------------------+-----------+-------------------+----+----+----+----------+--------------------+----------+--------------------+-----------------+-----------+--------------------+--------------------+-------------+----+--------------------+
# only showing top 20 rows

# %% [markdown]
# Criar as seguintes views (Priorize o uso de SQL para esta parte):
# Para cada companhia aérea trazer a rota(origem-destino) mais utilizada com as seguintes informações:
# 	Razão social da companhia aérea
# 	Nome Aeroporto de Origem
# 	ICAO do aeroporto de origem
# 	Estado/UF do aeroporto de origem
# 	Nome do Aeroporto de Destino
# 	ICAO do Aeroporto de destino
# 	Estado/UF do aeroporto de destino

# %%
df_vra = sc.sql(
"""
Select  ICAOEmpresaAerea,RazaoSocial, AeroportoOrigem, ICAOAerodromoOrigem, AeroportoOrigemEstado, AeroportoDestino, ICAOAerodromoDestino, AeroportoDestinoEstado from (
select
    a.RazaoSocial,
    ae.name AeroportoOrigem,
    ICAOEmpresaAerea,
    ICAOAerodromoOrigem,
    ae.state AeroportoOrigemEstado,
    ae2.name AeroportoDestino,
    ICAOAerodromoDestino,
    ae2.state AeroportoDestinoEstado,
    ROW_NUMBER() OVER(PARTITION BY ICAOEmpresaAerea order by count(concat(ICAOAerodromoOrigem,ICAOAerodromoDestino)) desc) NrLinha,
    MAX(count(concat(ICAOAerodromoOrigem,ICAOAerodromoDestino))) OVER(PARTITION BY ICAOEmpresaAerea, ICAOAerodromoOrigem, ICAOAerodromoDestino) origem_destino_counter
    from vra v
    Left join air_cia a on a.icao = v.ICAOEmpresaAerea
    Left join aerodromos ae on ae.icao = v.ICAOAerodromoOrigem
    Left join aerodromos ae2 on ae2.icao = v.ICAOAerodromoDestino

    group by ICAOEmpresaAerea, ICAOAerodromoOrigem, ICAOAerodromoDestino, a.RazaoSocial,ae.name, ae.state, AeroportoDestino, AeroportoOrigemEstado, AeroportoDestinoEstado
    order by ICAOEmpresaAerea) t
  
  where NrLinha = 1
   """)
df_vra.show(50)
# Out:
# +----------------+--------------------+--------------------+-------------------+---------------------+--------------------+--------------------+----------------------+
# |ICAOEmpresaAerea|         RazaoSocial|     AeroportoOrigem|ICAOAerodromoOrigem|AeroportoOrigemEstado|    AeroportoDestino|ICAOAerodromoDestino|AeroportoDestinoEstado|
# +----------------+--------------------+--------------------+-------------------+---------------------+--------------------+--------------------+----------------------+
# |             AAL|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Miami Internation...|                KMIA|               Florida|
# |             ACA|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Toronto Pearson I...|                CYYZ|               Ontario|
# |             ACN|AZUL CONECTA LTDA...|       Coari Airport|               SWKO|    State of Amazonas|Eduardo Gomes Int...|                SBEG|              Amazonas|
# |             ADB|                null|Johan Adolf Penge...|               SMJP|                 Para|Val de Cans Inter...|                SBBE|                  Pará|
# |             AEA|                null|Adolfo Suárez Mad...|               LEMD|  Comunidad de Madrid|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AFR|                null|Charles de Gaulle...|               LFPG|        Île-de-France|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AJB|                null|Jorge Newbery Air...|               SABE|         Buenos Aires|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AMX|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Mexico City Inter...|                MMMX|      Ciudad de México|
# |             ARE|                null|Alfonso Bonilla A...|               SKCL|      Valle del Cauca|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             ARG|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Ministro Pistarin...|                SAEZ|  Provincia de Buen...|
# |             ARL|                null|Mariscal Sucre In...|               SEQM|            Pichincha|Viracopos/Campina...|                SBKP|             São Paulo|
# |             ASO|AEROSUL TÁXI AÉRE...|Hercílio Luz Inte...|               SBFL|       Santa Catarina|     Caçador Airport|                SBCD|        Santa Catarina|
# |             ATG|                null|Blaise Diagne Int...|               GOBD|         Thiès Region|Frankfurt–Hahn Ai...|                EDFH|       Rheinland-Pfalz|
# |             AUZ|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Carrasco Gral. Ce...|                SUMU|  Departamento de C...|
# |             AVA|                null|El Dorado Interna...|               SKBO|               Bogotá|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AZA|                null|Milan–Malpensa Ai...|               LIMC|             Lombardy|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AZN|                null|Viru Viru Interna...|               SLVR| Departamento de S...|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AZP|                null|Silvio Pettirossi...|               SGAS| Departamento Central|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             AZU|AZUL LINHAS AÉREA...|Viracopos/Campina...|               SBKP|            São Paulo|Santos Dumont Air...|                SBRJ|        Rio de Janeiro|
# |             BAW|                null|    Heathrow Airport|               EGLL|              England|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             BOV|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Viru Viru Interna...|                SLVR|  Departamento de S...|
# |             CCA|                null|Adolfo Suárez Mad...|               LEMD|  Comunidad de Madrid|Beijing Capital I...|                ZBAA|               Beijing|
# |             CFG|                null|Rio de Janeiro–Ga...|               SBGL|       Rio de Janeiro|   Frankfurt Airport|                EDDF|                 Hesse|
# |             CJT|                null|Viracopos/Campina...|               SBKP|            São Paulo|Miami Internation...|                KMIA|               Florida|
# |             CKS|                null|Miami Internation...|               KMIA|              Florida|Viracopos/Campina...|                SBKP|             São Paulo|
# |             CLX|                null|Viracopos/Campina...|               SBKP|            São Paulo|Luxembourg Findel...|                ELLX|   Luxembourg District|
# |             CMP|                null|Tocumen Internati...|               MPTO|               Panamá|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             CSB|                null|Piarco Internatio...|               TTPP| Tunapuna/Piarco R...|Viracopos/Campina...|                SBKP|             São Paulo|
# |             CUB|                null|Simón Bolívar Int...|               SVMI|               Vargas|José Martí Intern...|                MUHA|                      |
# |             CVK|                null|Miami Internation...|               KMIA|              Florida|Eduardo Gomes Int...|                SBEG|              Amazonas|
# |             CXB|                null|Mexico City Inter...|               MMMX|     Ciudad de México|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             DAL|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Hartsfield–Jackso...|                KATL|               Georgia|
# |             DLH|                null|   Frankfurt Airport|               EDDF|                Hesse|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             DTA|                null|Quatro de Feverei...|               FNLU|      Luanda Province|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             EAL|                null|Tancredo Neves In...|               SBCF|         Minas Gerais|Miami Internation...|                KMIA|               Florida|
# |             EDR|                null|Val de Cans Inter...|               SBBE|                 Pará|Johan Adolf Penge...|                SMJP|                  Para|
# |             EDW|                null|Rio de Janeiro–Ga...|               SBGL|       Rio de Janeiro|      Zürich Airport|                LSZH|                Zürich|
# |             ETD|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Abu Dhabi Interna...|                OMAA|             Abu Dhabi|
# |             ETH|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Bole Internationa...|                HAAB|                Oromia|
# |             ETR|                null|Eduardo Gomes Int...|               SBEG|             Amazonas|Simón Bolívar Int...|                SVMI|                Vargas|
# |             FDX|                null|Memphis Internati...|               KMEM|            Tennessee|Viracopos/Campina...|                SBKP|             São Paulo|
# |             GCA|                null|Alfonso Bonilla A...|               SKCL|      Valle del Cauca|Viru Viru Interna...|                SLVR|  Departamento de S...|
# |             GEC|                null|   Frankfurt Airport|               EDDF|                Hesse|Viracopos/Campina...|                SBKP|             São Paulo|
# |             GLO|GOL LINHAS AÉREAS...|Santos Dumont Air...|               SBRJ|       Rio de Janeiro|São Paulo–Congonh...|                SBSP|             São Paulo|
# |             GTI|                null|Miami Internation...|               KMIA|              Florida|Viracopos/Campina...|                SBKP|             São Paulo|
# |             IBE|                null|Adolfo Suárez Mad...|               LEMD|  Comunidad de Madrid|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             ICV|                null|Mexico City Inter...|               MMMX|     Ciudad de México|Miami Internation...|                KMIA|               Florida|
# |             IPM|                null|São Paulo–Guarulh...|               SBGR|            São Paulo|Rio de Janeiro–Ga...|                SBGL|        Rio de Janeiro|
# |             ITY|                null|Leonardo da Vinci...|               LIRF|                Lazio|São Paulo–Guarulh...|                SBGR|             São Paulo|
# |             JAF|                null|Brussels Airport ...|               EBBR|           Vlaanderen|São Paulo–Guarulh...|                SBGR|             São Paulo|
# +----------------+--------------------+--------------------+-------------------+---------------------+--------------------+--------------------+----------------------+
# only showing top 50 rows

# %%
df = sc.sql("""
  select * from
  (select 
  ICAOAerodromoOrigem Aeroporto,
  ICAOEmpresaAerea CiaArea, 
  count(ICAOEmpresaAerea) as TotalPousoDecolagem,
  count(NumeroVoo) OVER(PARTITION BY ICAOAerodromoOrigem) QtdRotasAPartirDoAeroporto,
  count(NumeroVoo) OVER(PARTITION BY ICAOAerodromoDestino) QtdRotasDestinoAeroporto,
  ROW_NUMBER() OVER(PARTITION BY ICAOAerodromoOrigem order by count(ICAOEmpresaAerea) desc ) NrLinha
  from vra 
  where CAST(partida_real as date) between '2021-01-01' and '2021-12-31'
  group by ICAOAerodromoOrigem, ICAOEmpresaAerea, NumeroVoo,ICAOAerodromoDestino)t
  where NrLinha = 1 """)
  
df.show()
# Out:
# +---------+-------+-------------------+--------------------------+------------------------+-------+
# |Aeroporto|CiaArea|TotalPousoDecolagem|QtdRotasAPartirDoAeroporto|QtdRotasDestinoAeroporto|NrLinha|
# +---------+-------+-------------------+--------------------------+------------------------+-------+
# |     KATL|    DAL|                331|                         2|                    1663|      1|
# |     LFPG|    AFR|                278|                         8|                    1663|      1|
# |     SBPS|    PTB|                306|                       185|                     358|      1|
# |     EDDK|    PVG|                  1|                         1|                    1663|      1|
# |     SBIH|    PAM|                140|                         7|                     328|      1|
# |     SBSJ|    OWT|                  2|                         8|                      82|      1|
# |     SSSC|    OWT|                 14|                         2|                     420|      1|
# |     OTHH|    QTR|                297|                         5|                    1663|      1|
# |     SBCH|    AZU|                306|                        39|                     883|      1|
# |     SCCF|    LAE|                  1|                         2|                     883|      1|
# |     FYWH|    PVV|                  1|                         1|                       2|      1|
# |     SBCR|    AZU|                100|                         3|                     883|      1|
# |     UCFM|    PVV|                  2|                         1|                       1|      1|
# |     SDWQ|    OWT|                 14|                         1|                       3|      1|
# |     SNEE|    OWT|                 12|                         2|                       4|      1|
# |     OMAA|    ETD|                  2|                         6|                       1|      1|
# |     PANC|    KAL|                127|                         1|                     133|      1|
# |     SBUG|    AZU|                 90|                         6|                     420|      1|
# |     SWPH|    OWT|                  1|                         1|                       9|      1|
# |     SBSG|    AZU|                244|                       136|                     414|      1|
# +---------+-------+-------------------+--------------------------+------------------------+-------+
# only showing top 20 rows
